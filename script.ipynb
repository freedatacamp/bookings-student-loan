# %%
import pandas as pd

# %%
df_first_year = pd.read_csv('01_first_year_new_volume.csv')
df_parent_repay = pd.read_csv('15_parent_repay_outcomes.csv')

# %%
df_first_year.head()
# Out:
#      fy  full_sample  sel_index  typen  new_borrowers  new_undergrad_bor  \
# 0  1970          1.0        NaN    NaN            203                190
# 1  1971          1.0        NaN    NaN            148                137
# 2  1972          1.0        NaN    NaN            139                128
# 3  1973          1.0        NaN    NaN            135                123
# 4  1974          1.0        NaN    NaN            141                128
#
#    new_grad_bor  new_parplus_bor  tot_vol  undergrad_loans       ...        \
# 0            13                0      242              222       ...
# 1            11                0      195              179       ...
# 2            11                0      196              179       ...
# 3            12                0      204              181       ...
# 4            13                0      236              207       ...
#
#    median_hh_inc  pct_black  poverty_rate  unemp_rate  md_fam_inc  \
# ...

# %%
df_parent_repay.head()
# Out:
#      fy  full_sample  sel_index  typen  enter_repay_borrowers  lst_sel_index1  \
# 0  1981          1.0        NaN    NaN                      4           0.040
# 1  1982          1.0        NaN    NaN                      7           0.089
# 2  1983          1.0        NaN    NaN                     20           0.149
# 3  1984          1.0        NaN    NaN                     30           0.220
# 4  1985          1.0        NaN    NaN                     42           0.214
#
#    lst_sel_index2  lst_sel_index3  lst_sel_index4  lst_typen1    ...     \
# 0           0.126           0.189           0.646       0.034    ...
# 1           0.146           0.214           0.552       0.078    ...
# 2           0.177           0.252           0.422       0.093    ...
# 3           0.175           0.226           0.379       0.149    ...
# 4           0.146           0.242           0.398       0.145    ...
#
# ...

# %%
df_first_year.describe()
# Out:
#                 fy  full_sample   sel_index       typen  new_borrowers  \
# count   585.000000         45.0  270.000000  270.000000     585.000000
# mean   1992.000000          1.0    3.500000    3.500000     372.743590
# std      12.998288          0.0    1.710997    1.710997     494.935428
# min    1970.000000          1.0    1.000000    1.000000       1.000000
# 25%    1981.000000          1.0    2.000000    2.000000      76.000000
# 50%    1992.000000          1.0    3.500000    3.500000     230.000000
# 75%    2003.000000          1.0    5.000000    5.000000     465.000000
# max    2014.000000          1.0    6.000000    6.000000    3304.000000
#
#        new_undergrad_bor  new_grad_bor  new_parplus_bor       tot_vol  \
# count         585.000000    585.000000       585.000000    585.000000
# mean          321.902564     22.054701        28.916239   1927.873504
# std           430.526150     40.056387        47.045571   3242.536400
# ...

# %%
df_parent_repay.describe()
# Out:
#                 fy  full_sample   sel_index       typen  \
# count   291.000000         34.0  130.000000  127.000000
# mean   1998.305842          1.0    3.276923    3.330709
# std       9.392914          0.0    1.489058    1.947954
# min    1981.000000          1.0    1.000000    1.000000
# 25%    1990.000000          1.0    3.000000    2.000000
# 50%    1998.000000          1.0    4.000000    4.000000
# 75%    2006.000000          1.0    5.000000    6.000000
# max    2014.000000          1.0    5.000000    6.000000
#
#        enter_repay_borrowers  lst_sel_index1  lst_sel_index2  lst_sel_index3  \
# count             291.000000       34.000000       34.000000       34.000000
# mean               65.381443        0.239588        0.164941        0.264294
# std                69.464818        0.071715        0.015702        0.034885
# min                 3.000000        0.040000        0.126000        0.189000
# ...

# %%
df.values
# Out:
# array([[  1.97000000e+03,   1.00000000e+00,              nan, ...,
#                      nan,              nan,              nan],
#        [  1.97100000e+03,   1.00000000e+00,              nan, ...,
#                      nan,              nan,              nan],
#        [  1.97200000e+03,   1.00000000e+00,              nan, ...,
#                      nan,              nan,              nan],
#        ...,
#        [  2.01200000e+03,              nan,              nan, ...,
#           5.59400000e+04,   3.41950000e+04,   2.78200000e+04],
#        [  2.01300000e+03,              nan,              nan, ...,
#           5.58150000e+04,   3.36350000e+04,   2.55250000e+04],
#        [  2.01400000e+03,              nan,              nan, ...,
#           5.64500000e+04,   3.23950000e+04,   1.97600000e+04]])

# %%
df.describe()
# Out:
#                 fy  full_sample   sel_index       typen  new_borrowers  \
# count   585.000000         45.0  270.000000  270.000000     585.000000
# mean   1992.000000          1.0    3.500000    3.500000     372.743590
# std      12.998288          0.0    1.710997    1.710997     494.935428
# min    1970.000000          1.0    1.000000    1.000000       1.000000
# 25%    1981.000000          1.0    2.000000    2.000000      76.000000
# 50%    1992.000000          1.0    3.500000    3.500000     230.000000
# 75%    2003.000000          1.0    5.000000    5.000000     465.000000
# max    2014.000000          1.0    6.000000    6.000000    3304.000000
#
#        new_undergrad_bor  new_grad_bor  new_parplus_bor       tot_vol  \
# count         585.000000    585.000000       585.000000    585.000000
# mean          321.902564     22.054701        28.916239   1927.873504
# std           430.526150     40.056387        47.045571   3242.536400
# ...

# %%
df.new_borrowers.describe()
# Out:
# count     585.000000
# mean      372.743590
# std       494.935428
# min         1.000000
# 25%        76.000000
# 50%       230.000000
# 75%       465.000000
# max      3304.000000
# Name: new_borrowers, dtype: float64

# %%
df = pd.read_csv('15_parent_repay_outcomes.csv')

# %%
df.describe()
# Out:
#                 fy  full_sample   sel_index       typen  \
# count   291.000000         34.0  130.000000  127.000000
# mean   1998.305842          1.0    3.276923    3.330709
# std       9.392914          0.0    1.489058    1.947954
# min    1981.000000          1.0    1.000000    1.000000
# 25%    1990.000000          1.0    3.000000    2.000000
# 50%    1998.000000          1.0    4.000000    4.000000
# 75%    2006.000000          1.0    5.000000    6.000000
# max    2014.000000          1.0    5.000000    6.000000
#
#        enter_repay_borrowers  lst_sel_index1  lst_sel_index2  lst_sel_index3  \
# count             291.000000       34.000000       34.000000       34.000000
# mean               65.381443        0.239588        0.164941        0.264294
# std                69.464818        0.071715        0.015702        0.034885
# min                 3.000000        0.040000        0.126000        0.189000
# ...

# %%
df.columns
# Out:
# Index(['fy', 'full_sample', 'sel_index', 'typen', 'enter_repay_borrowers',
#        'lst_sel_index1', 'lst_sel_index2', 'lst_sel_index3', 'lst_sel_index4',
#        'lst_typen1', 'lst_typen2', 'lst_typen3', 'lst_typen4',
#        'tot_parplus_balance', 'f5_tot_parplus_balance', 'mn_parplus_loan',
#        'md_parplus_loan', 'pct75_par', 'pct90_par', 'alt_cdr2', 'alt_cdr3',
#        'alt_cdr5', 'fract', 'age_entry', 'cpi_adj'],
#       dtype='object')
